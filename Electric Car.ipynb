# %%
import pandas as pd
'''
https://bigdata.kepco.co.kr/cmsmain.do?scode=S01&pcode=000170
한국전력 - 전국 전기차 충전소 설치 현황
'''
df = pd.read_excel('Electric.xls')
df
# Out:
#           전기차 충전소 설치현황 ( 20210624 현재 )  Unnamed: 1                 Unnamed: 2  \
# 0     시도 : 전체(시도), 시군구 : 전체(시 / 군 / 구)         NaN                        NaN
# 1                                   시구        설치장소                         주소
# 2                                   전체     가평종합운동장                          -
# 3                                   전체        가평지사     경기도 가평군 가평읍 가화로 169-11
# 4                                   전체    가평하수도사업소        경기도 가평군 가평읍 달전리 364
# ...                                ...         ...                        ...
# 3953                                전체     화정글샘도서관          경상남도 김해시 삼계동 1437
# 3954                                전체      화천민원센터  경상남도 창원시 의창구 북면 천주로 483-7
# 3955                                전체  황성동 행정복지센터           경상북도 경주시 황성동 167
# 3956                                전체  휴먼빌2단지 아파트     경상남도 창원시 의창구 북면 동곡로 35
# 3957                                전체        휴플러스        전라북도 진안군 진안읍 진용로 64
#
#      Unnamed: 3 Unnamed: 4                                         Unnamed: 5
# 0           NaN        NaN                                                NaN
# 1      급속충전기(대)   완속충전기(대)                                               지원차종
# 2            1          0                                         SM3 Z.E,테슬라
# 3            1          1   SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트E...
# 4            1          0                                         SM3 Z.E,테슬라
# ...         ...        ...                                                ...
# 3953         1          0   SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트E...
# 3954         1          0   SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트E...
# 3955         1          0                                         SM3 Z.E,테슬라
# 3956         1          0   SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트E...
# 3957         0          1             레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV
#
# [3958 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3959 entries, 0 to 3958
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       3958 non-null   float64
#  1   1       3959 non-null   object
#  2   2       3958 non-null   object
#  3   3       3958 non-null   object
#  4   4       3958 non-null   object
#  5   5       3958 non-null   object
#  6   6       3958 non-null   object
# dtypes: float64(1), object(6)
# memory usage: 216.6+ KB

# %% [markdown]
# ## - 전국 전기차 충전소 설치현황

# %%
df1 = df.rename(columns=df.iloc[1])
df1.head(10)
# Out:
#                                  시구       설치장소                      주소  \
# 0  시도 : 전체(시도), 시군구 : 전체(시 / 군 / 구)        NaN                     NaN
# 1                                시구       설치장소                      주소
# 2                                전체    가평종합운동장                       -
# 3                                전체       가평지사  경기도 가평군 가평읍 가화로 169-11
# 4                                전체   가평하수도사업소     경기도 가평군 가평읍 달전리 364
# 5                                전체      상면사무소    경기도 가평군 상면 연하리 171-1
# 6                                전체     설악면사무소   경기도 가평군 설악면 신천리 156-1
# 7                                전체     조종면사무소    경기도 가평군 조종면 현리 567-7
# 8                                전체  LH강남힐스테이트  서울특별시 강남구 자곡동 자곡로3길 21
# 9                                전체     LH서울지사   서울특별시 강남구 선릉로 121길 12
#
#    급속충전기(대)  완속충전기(대)                                               지원차종
# 0       NaN       NaN                                                NaN
# 1  급속충전기(대)  완속충전기(대)                                               지원차종
# 2        1         0                                         SM3 Z.E,테슬라
# 3        1         1   SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트E...
# 4        1         0                                         SM3 Z.E,테슬라
# 5        1         0   SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트E...
# 6        1         0   SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트E...
# 7        1         0   SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트E...
# 8        1         4   SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트E...
# 9        1         0   SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트E...

# %%
split_comma = ','.join(df1['지원차종'].astype(str))
split_comma
# Out:
# 'nan,지원차종,SM3 Z.E,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라,SM ...

# %%
ev = []
for comma in split_comma.split(','):
    ev.append(str(comma).strip())
    
ev
# Out:
# ['nan',
#  '지원차종',
#  'SM3 Z.E',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  'BMW i3',
#  '스파크EV',
#  '볼트EV',
#  '테슬라',
#  'SM3 Z.E',
#  '레이EV',
#  '소울EV',
#  '닛산리프',
#  '아이오닉EV',
#  ...]

# %%
from collections import Counter #자동 중복제거 + 중복제거된 유일값 카운트
ev_val = Counter(ev)
print(ev_val)
# Out:
# Counter({'SM3 Z.E': 3797, '테슬라': 3797, 'BMW i3': 3444, '스파크EV': 3439, '볼트EV': 3439, '레이EV': 3436, '소울EV': 3436, '닛산리프': 3436, '아이오닉EV': 3436, '': 7, 'nan': 1, '지원차종': 1})

# %%
df3 = pd.DataFrame(ev_val, index = [0])
df3
# Out:
#    nan  지원차종  SM3 Z.E   테슬라  레이EV  소울EV  닛산리프  아이오닉EV  BMW i3  스파크EV  볼트EV
# 0    1     1     3797  3797  3436  3436  3436    3436    3444   3439  3439  7

# %%
df3.columns = ['0','0','SM3 Z.Ez','테슬라','레이EV','소울EV','닛산리프','아이오닉EV'
              ,'BMW i3','스파크EV', '볼트EV','공백']
df3
# Out:
#    0  0  SM3 Z.Ez   테슬라  레이EV  소울EV  닛산리프  아이오닉EV  BMW i3  스파크EV  볼트EV  공백
# 0  1  1      3797  3797  3436  3436  3436    3436    3444   3439  3439   7

# %%
df3 = df3.drop(['0','0','공백'], axis =1 ) # 유의미 칼럼 추출
df3
# Out:
#    SM3 Z.Ez   테슬라  레이EV  소울EV  닛산리프  아이오닉EV  BMW i3  스파크EV  볼트EV
# 0      3797  3797  3436  3436  3436    3436    3444   3439  3439

# %%
df3[:].apply(pd.to_numeric)
df3.dtypes # str → int
# Out:
# SM3 Z.Ez    int64
# 테슬라         int64
# 레이EV        int64
# 소울EV        int64
# 닛산리프        int64
# 아이오닉EV      int64
# BMW i3      int64
# 스파크EV       int64
# 볼트EV        int64
# dtype: object

# %%
print(list(df3.loc[0]))
# Out:
# [3797, 3797, 3436, 3436, 3436, 3436, 3444, 3439, 3439]

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
'''
전기차를 구매하거나 사용하려면
SM3 Z.Ez, 테슬라 > 레이EV, 소울EV, 닛산리프, 아이오닉EV > BMW i3 > 스파크EV, 볼트EV
순서대로 충전에 유리하다

'''
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font) # 깨짐
x = df3.columns
y = df3.loc[0]
plt.barh(x, y
        ,align='edge'
       ,color = 'blue'
       ,alpha = 0.4) # plt.barh라벨 위치 변경

plt.title('전국 전기차 이용', fontsize=20)
plt.xlabel('지원수',fontsize=18)
plt.ylabel('차종', fontsize=18)

plt.show()

# %% [markdown]
# ## 전국 지역데이터 합쳐서 지역별 전기차 충전지원 그래프 시각화

# %%
df2 = df1.iloc[2:]
df2
# Out:
#       시구        설치장소                         주소 급속충전기(대) 완속충전기(대)  \
# 2     전체     가평종합운동장                          -       1        0
# 3     전체        가평지사     경기도 가평군 가평읍 가화로 169-11       1        1
# 4     전체    가평하수도사업소        경기도 가평군 가평읍 달전리 364       1        0
# 5     전체       상면사무소       경기도 가평군 상면 연하리 171-1       1        0
# 6     전체      설악면사무소      경기도 가평군 설악면 신천리 156-1       1        0
# ...   ..         ...                        ...      ...      ...
# 3953  전체     화정글샘도서관          경상남도 김해시 삼계동 1437       1        0
# 3954  전체      화천민원센터  경상남도 창원시 의창구 북면 천주로 483-7       1        0
# 3955  전체  황성동 행정복지센터           경상북도 경주시 황성동 167       1        0
# 3956  전체  휴먼빌2단지 아파트     경상남도 창원시 의창구 북면 동곡로 35       1        0
# 3957  전체        휴플러스        전라북도 진안군 진안읍 진용로 64       0        1
#
#                                                    지원차종
# 2                                           SM3 Z.E,테슬라
# 3     SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트E...
# 4                                           SM3 Z.E,테슬라
# 5     SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트E...
# 6     SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트E...
# ...                                                 ...
# 3953  SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트E...
# 3954  SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트E...
# 3955                                        SM3 Z.E,테슬라
# 3956  SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트E...
# 3957            레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV
#
# [3956 rows x 6 columns]

# %%
df2[['설치장소','주소','지원차종']]
# Out:
#             설치장소                         주소  \
# 2        가평종합운동장                          -
# 3           가평지사     경기도 가평군 가평읍 가화로 169-11
# 4       가평하수도사업소        경기도 가평군 가평읍 달전리 364
# 5          상면사무소       경기도 가평군 상면 연하리 171-1
# 6         설악면사무소      경기도 가평군 설악면 신천리 156-1
# ...          ...                        ...
# 3953     화정글샘도서관          경상남도 김해시 삼계동 1437
# 3954      화천민원센터  경상남도 창원시 의창구 북면 천주로 483-7
# 3955  황성동 행정복지센터           경상북도 경주시 황성동 167
# 3956  휴먼빌2단지 아파트     경상남도 창원시 의창구 북면 동곡로 35
# 3957        휴플러스        전라북도 진안군 진안읍 진용로 64
#
#                                                    지원차종
# 2                                           SM3 Z.E,테슬라
# 3     SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트E...
# 4                                           SM3 Z.E,테슬라
# 5     SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트E...
# 6     SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트E...
# ...                                                 ...
# 3953  SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트E...
# 3954  SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트E...
# 3955                                        SM3 Z.E,테슬라
# 3956  SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트E...
# 3957            레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV
#
# [3956 rows x 3 columns]

# %% [markdown]
# ##  - 지역별 전기차 충전소 설치량(급속 / 완속) 순위
